# %%
import glob, json, os, uuid, shutil, io, csv, hashlib
from pymongo import MongoClient

# %%
client = MongoClient("mongodb://localhost:27017/flashcards", maxPoolSize=18238296)
db = client["flashcards"]

# %%
TOPICS_FOLDER = "flashes"

# %%
with open("flashes/First Level Characters.json") as r:
    data = json.load(r)
    data["id"] = None
    db.topics.insert_one(data)
# Out:
# ---------------------------------------------------------------------------
# DocumentTooLarge                          Traceback (most recent call last)
# Cell In[10], line 4
#       2 data = json.load(r)
#       3 data["id"] = None
# ----> 4 db.topics.insert_one(data)
#
# File ~/Desktop/Coding/Projects/FlashCards/lib/python3.9/site-packages/pymongo/synchronous/collection.py:891, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     887     document["_id"] = ObjectId()  # type: ignore[index]
#     889 write_concern = self._write_concern_for(session)
#     890 return InsertOneResult(
# --> 891     self._insert_one(
#     892         document,
#     893         ordered=True,
#     894         write_concern=write_concern,
#     895         op_id=None,
#     896         bypass_doc_val=bypass_document_validation,
#     897         session=session,
#     898         comment=comment,
#     899     ),
#     900     write_concern.acknowledged,
# ...
